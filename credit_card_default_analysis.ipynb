# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\momin\OneDrive\Desktop\Git_Projects\Credit_card_default\working_credit_card_instances_data.csv")
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.describe().T
# Out:
#                               count           mean            std       min  \
# ID                          30000.0   15000.500000    8660.398374       1.0
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          30000 non-null  int64
#  1   limit_bal                   30000 non-null  int64
#  2   sex                         30000 non-null  int64
#  3   education                   30000 non-null  int64
#  4   marriage                    30000 non-null  int64
#  5   age                         30000 non-null  int64
#  6   pay_0                       30000 non-null  int64
#  7   pay_2                       30000 non-null  int64
#  8   pay_3                       30000 non-null  int64
#  9   pay_4                       30000 non-null  int64
#  10  pay_5                       30000 non-null  int64
#  11  pay_6                       30000 non-null  int64
#  12  bill_amt1                   30000 non-null  int64
# ...

# %%
gender_map = {
    1 : 'male',
    2 : 'female'
}

df['sex'] = df['sex'].map(gender_map)

# %%
education_map = {
    1 : 'graduate school',
    2 : 'university',
    3 : 'high school',
    4 : 'others'
}

df['education'] = df['education'].map(education_map)

# %%
marriage_map = {
    1 : 'married',
    2 : 'single',
    3 : 'others'
}

df['marriage'] = df['marriage'].map(marriage_map)

# %%
df['default_flag'] = df['default payment next month'].apply(lambda x: 'Yes' if x == 1 else 'No')

# %%
df.head()
# Out:
#    id  limit_bal     sex   education marriage  age  pay_0  pay_2  pay_3  \
# 0   1      20000  female  university  married   24      2      2     -1
# 1   2     120000  female  university   single   26     -1      2      0
# 2   3      90000  female  university   single   34      0      0      0
# 3   4      50000  female  university  married   37      0      0      0
# 4   5      50000    male  university  married   57     -1      0     -1
#
#    pay_4  ...  bill_amt5  bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  \
# 0     -1  ...          0          0         0       689         0         0
# 1      0  ...       3455       3261         0      1000      1000      1000
# 2      0  ...      14948      15549      1518      1500      1000      1000
# 3      0  ...      28959      29547      2000      2019      1200      1100
# 4      0  ...      19146      19131      2000     36681     10000      9000
#
#    pay_amt5  pay_amt6  default payment next month  default_flag
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          30000 non-null  int64
#  1   limit_bal                   30000 non-null  int64
#  2   sex                         30000 non-null  object
#  3   education                   29655 non-null  object
#  4   marriage                    29946 non-null  object
#  5   age                         30000 non-null  int64
#  6   pay_0                       30000 non-null  int64
#  7   pay_2                       30000 non-null  int64
#  8   pay_3                       30000 non-null  int64
#  9   pay_4                       30000 non-null  int64
#  10  pay_5                       30000 non-null  int64
#  11  pay_6                       30000 non-null  int64
#  12  bill_amt1                   30000 non-null  int64
# ...

# %% [markdown]
# ## Categorical Analysis

# %%
categorical_columns = df.select_dtypes(include = 'object').columns.tolist()
print(categorical_columns)
# Out:
# ['sex', 'education', 'marriage', 'default_flag']

# %%
for col in categorical_columns:
    print(f"\n--- {col.upper()} ---\n")
    print(df[col].value_counts(dropna = False))
    plt.figure(figsize = (4, 6))
    sns.countplot(x = col, data = df, order = df[col].value_counts().index)
    plt.title(f'{col.capitalize()} Distribution')
    plt.xlabel(col.capitalize())
    plt.ylabel('Count')
    plt.xticks(rotation=30)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
# Out:
# --- SEX ---
#
# sex
# female    18112
# male      11888
# Name: count, dtype: int64
# --- EDUCATION ---
#
# education
# university         14030
# graduate school    10585
# high school         4917
# NaN                  345
# others               123
# Name: count, dtype: int64
# --- MARRIAGE ---
#
# marriage
# single     15964
# married    13659
# others       323
# NaN           54
# Name: count, dtype: int64
# --- DEFAULT_FLAG ---
#
# default_flag
# No     23364
# Yes     6636
# Name: count, dtype: int64

# %%
df['education'] = df['education'].fillna('Unknown')
df['marriage'] = df['marriage'].fillna('Unknown')

# %%
print(df['education'].unique())
# Out:
# ['university' 'graduate school' 'high school' 'Unknown' 'others']

# %%
print(df['marriage'].unique())
# Out:
# ['married' 'single' 'others' 'Unknown']

# %%
for col in categorical_columns:
    print(f"\n --- Default Rate by {col.upper()} ---\n")
    result = pd.crosstab(df[col], df['default_flag'], normalize = 'index') * 100
    print(result.round(2))
# Out:
#  --- Default Rate by SEX ---
#
# default_flag     No    Yes
# sex
# female        79.22  20.78
# male          75.83  24.17
#
#  --- Default Rate by EDUCATION ---
#
# default_flag        No    Yes
# education
# Unknown          92.46   7.54
# graduate school  80.77  19.23
# high school      74.84  25.16
# others           94.31   5.69
# university       76.27  23.73
#
#  --- Default Rate by MARRIAGE ---
#
# default_flag     No    Yes
# marriage
# Unknown       90.74   9.26
# married       76.53  23.47
# others        73.99  26.01
# single        79.07  20.93
#
#  --- Default Rate by DEFAULT_FLAG ---
#
# default_flag     No    Yes
# default_flag
# No            100.0    0.0
# Yes             0.0  100.0

# %%
# Chi-Square Test of Independence

from scipy.stats import chi2_contingency

cat_columns_not_default = ['sex', 'education', 'marriage']

for col in cat_columns_not_default:
    table = pd.crosstab(df[col], df['default_flag'])
    chi2, p, dof, expected = chi2_contingency(table)
    
    print(f"\n--- Chi-Square Test: {col.upper()} ---")
    print(f"Chi² Statistic = {chi2:.2f}")
    print(f"Degrees of Freedom = {dof}")
    print(f"P-value = {p:.4f}")
    
    if p < 0.05:
        print("Significant relationship with default_flag (reject null hypothesis)")
    else:
        print("Not significant (fail to reject null hypothesis)")
# Out:
# --- Chi-Square Test: SEX ---
# Chi² Statistic = 47.71
# Degrees of Freedom = 1
# P-value = 0.0000
# Significant relationship with default_flag (reject null hypothesis)
#
# --- Chi-Square Test: EDUCATION ---
# Chi² Statistic = 160.59
# Degrees of Freedom = 4
# P-value = 0.0000
# Significant relationship with default_flag (reject null hypothesis)
#
# --- Chi-Square Test: MARRIAGE ---
# Chi² Statistic = 35.66
# Degrees of Freedom = 3
# P-value = 0.0000
# Significant relationship with default_flag (reject null hypothesis)

# %%
print(f"True p-value = {p}")
# Out:
# True p-value = 8.825862457577375e-08

# %%
import numpy as np
from scipy.stats import chi2_contingency

def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min(k - 1, r - 1))

for col in cat_columns_not_default:
    table = pd.crosstab(df[col], df['default_flag'])
    v = cramers_v(table)
    print(f"Cramér’s V for {col}: {v:.4f}")
# Out:
# Cramér’s V for sex: 0.0399
# Cramér’s V for education: 0.0732
# Cramér’s V for marriage: 0.0345

# %% [markdown]
# ### **Categorical Analysis Observation:**
#
# - Even though all three variables are statistically significant (Chi-Square p < 0.05), their real-world influence on default behavior is very small.
#
# - These categorical variables do impact default likelihood, but only slightly.
#
# - Most of the predictive power likely lies in the numerical variables, such as: repayment history, credit limit, billing amount, and payments made.

# %% [markdown]
# ## Numerical Analysis

# %%
numerical_columns = [
    'limit_bal', 'age',
    'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6',
    'bill_amt1', 'bill_amt2', 'bill_amt3', 'bill_amt4', 'bill_amt5', 'bill_amt6',
    'pay_amt1', 'pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6'
]

# %%
df[numerical_columns].describe().T
# Out:
#              count           mean            std       min       25%  \
# limit_bal  30000.0  167484.322667  129747.661567   10000.0  50000.00
# age        30000.0      35.485500       9.217904      21.0     28.00
# pay_0      30000.0      -0.016700       1.123802      -2.0     -1.00
# pay_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# pay_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# pay_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# pay_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# pay_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# bill_amt1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# bill_amt2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# bill_amt3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# bill_amt4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# bill_amt5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# ...

# %%
for col in numerical_columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Distribution of {col}')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
for col in numerical_columns:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df[numerical_columns].corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap of Numerical Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation Heatmap Summary
#
# 1. **🟥 Strong Internal Correlations**
#    - bill_amt1 to bill_amt6 are highly correlated (r = 0.83 to 0.95), suggesting they capture the same underlying pattern, customers’ billing amounts over time.
#    - pay_0 to pay_6 are also strongly correlated (r = 0.47 to 0.82), indicating that repayment behavior is repetitive, customers who delay once tend to delay again.
#
# 2. **🟧 Moderate Relationships**
#    - pay_amt1 to pay_amt6 show moderate correlations (r = 0.15 to 0.31), reflecting consistent monthly payment habits.
#    - limit_bal is moderately positively correlated with both bill_amt and pay_amt features (r = 0.28 to 0.30), meaning higher credit limits often correspond to higher bills and payments.
#
# 3. **🟦 Weak or No Correlation**
#    - age has very weak correlations across all features (r ≈ 0.02 to 0.14), showing it has minimal influence on financial behavior or default risk.
#    - limit_bal is moderately negatively correlated with pay_0 to pay_6 (r ≈ -0.25 to -0.30), suggesting higher-limit customers tend to repay more reliably.

# %%
from scipy.stats import ttest_ind

numerical_columns = [
    'limit_bal', 'age',
    'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6',
    'bill_amt1', 'bill_amt2', 'bill_amt3', 'bill_amt4', 'bill_amt5', 'bill_amt6',
    'pay_amt1', 'pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6'
]

print(f"{'Feature':<15} {'P-Value':<12} {'Significant (<0.05)':<20}")
print('-'*50)

for col in numerical_columns:
    group1 = df[df['default payment next month'] == 1][col]  # Defaulters
    group2 = df[df['default payment next month'] == 0][col]  # Non-defaulters
    
    t_stat, p_val = ttest_ind(group1, group2, equal_var=False)
    
    is_significant = 'Yes' if p_val < 0.05 else 'No'
    print(f"{col:<15} {p_val:<12.4e} {is_significant:<20}")
# Out:
# Feature         P-Value      Significant (<0.05)
# --------------------------------------------------
# limit_bal       3.3641e-178  Yes
# age             2.0386e-02   Yes
# pay_0           0.0000e+00   Yes
# pay_2           7.5025e-302  Yes
# pay_3           8.3931e-245  Yes
# pay_4           3.8874e-200  Yes
# pay_5           5.6431e-175  Yes
# pay_6           7.3556e-151  Yes
# bill_amt1       6.8189e-04   Yes
# bill_amt2       1.4437e-02   Yes
# bill_amt3       1.3945e-02   Yes
# bill_amt4       7.8642e-02   No
# bill_amt5       2.4513e-01   No
# bill_amt6       3.5228e-01   No
# pay_amt1        3.5459e-68   Yes
# pay_amt2        1.8820e-49   Yes
# pay_amt3        1.7806e-32   Yes
# pay_amt4        3.3748e-34   Yes
# pay_amt5        3.2358e-29   Yes
# pay_amt6        2.5914e-28   Yes

# %%
grouped_means = df.groupby('default payment next month')[numerical_columns].mean().T
grouped_means.columns = ['No Default', 'Default']
grouped_means['Difference'] = grouped_means['Default'] - grouped_means['No Default']
grouped_means.round(2)
# Out:
#            No Default    Default  Difference
# limit_bal   178099.73  130109.66   -47990.07
# age             35.42      35.73        0.31
# pay_0           -0.21       0.67        0.88
# pay_2           -0.30       0.46        0.76
# pay_3           -0.32       0.36        0.68
# pay_4           -0.36       0.25        0.61
# pay_5           -0.39       0.17        0.56
# pay_6           -0.41       0.11        0.52
# bill_amt1    51994.23   48509.16    -3485.06
# bill_amt2    49717.44   47283.62    -2433.82
# bill_amt3    47533.37   45181.60    -2351.77
# bill_amt4    43611.17   42036.95    -1574.21
# bill_amt5    40530.45   39540.19     -990.25
# bill_amt6    39042.27   38271.44     -770.83
# pay_amt1      6307.34    3397.04    -2910.29
# pay_amt2      6640.47    3388.65    -3251.82
# pay_amt3      5753.50    3367.35    -2386.15
# pay_amt4      5300.53    3155.63    -2144.90
# pay_amt5      5248.22    3219.14    -2029.08
# pay_amt6      5719.37    3441.48    -2277.89

# %% [markdown]
# ### Statistical Insights: Numerical Variables vs Default
#
# - Customers who defaulted had significantly lower credit limits, lower monthly payments, and more frequent payment delays across all repayment status columns (pay_0 to pay_6).
# - Repayment behavior (pay_0 to pay_6) is the Strongest predictor, showing that defaulters consistently fell behind on payments.
# - Defaulters also paid ~2000–3000 less per month compared to non-defaulters.
# - The last 3 months of bill_amt showed no significant difference suggesting that billing history alone isn’t a strong standalone predictor.
